# %%
import xarray as xr
import coup_ppe

# %%
coup_ppe.parallel.daskhelper?
# Out:
# Type:        module
# String form: <module 'coup_ppe.parallel.daskhelper' from '/glade/u/home/bbuchovecky/coup_ppe/src/coup_ppe/parallel/daskhelper.py'>
# File:        ~/coup_ppe/src/coup_ppe/parallel/daskhelper.py
# Docstring:   Docstring for coup_ppe.parallel.daskhelper

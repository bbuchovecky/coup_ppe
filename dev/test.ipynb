# %%
import xarray as xr
import intake
import coup_ppe.access.load
import coup_ppe.metadata.members
import coup_ppe.parallel.daskhelper

# %%
# cat = intake.open_esm_datastore("/glade/u/home/bbuchovecky/coup_ppe/src/coup_ppe/catalog/pisom_timeseries_catalog_glade.json")

# %%
cat = coup_ppe.access.load.query_catalog(
    ensemble="pisom",
    varname=["TREFHT"],
    component="atm",
    frequency="month_1",
    member="0",
    # stream="h0"
)

# %%
cat.df
# Out:
#   member version component stream variable  \
# 0      0    <NA>       atm     h0   TREFHT
# 1      0    <NA>       atm     h1   TREFHT
#
#                                                 path  \
# 0  /glade/campaign/cgd/tss/czarakas/CoupledPPE/co...
# 1  /glade/campaign/cgd/tss/czarakas/CoupledPPE/co...
#
#              variable_long_name frequency time_steps                start  \
# 0  Reference height temperature   month_1     1680.0  0049-01-16 12:00:00
# 1  Reference height temperature   month_1     1680.0  0049-02-01 00:00:00
#
#                    end
# 0  0188-12-16 12:00:00
# 1  0189-01-01 00:00:00

# %%
var_cat = cat.search(variable=["TREFHT"])

# %%
ds_dict = var_cat.to_dataset_dict(
    xarray_open_kwargs={"use_cftime": True, "drop_variables": ["var"]},
    xarray_combine_by_coords_kwargs={"join": "outer"},
    preprocess=lambda x: x.sel(time=slice("0050-01", "0184-12")),
    threaded=True,
    progressbar=False,
)

# %%
q = {}
len(q)
# Out:
# 0

# %%
list(ds_dict.values())[0]
# Out:
# <xarray.Dataset> Size: 3GB
# Dimensions:    (member: 37, time: 1620, lat: 96, lon: 144, nbnd: 2)
# Coordinates:
#   * member     (member) object 296B '0' '1' '10' '11' '12' ... '6' '7' '8' '9'
#   * time       (time) object 13kB 0050-01-16 12:00:00 ... 0184-12-16 12:00:00
#   * lat        (lat) float64 768B -90.0 -88.11 -86.21 ... 86.21 88.11 90.0
#   * lon        (lon) float64 1kB 0.0 2.5 5.0 7.5 ... 350.0 352.5 355.0 357.5
#     time_bnds  (time, nbnd) object 26kB dask.array<chunksize=(1620, 2), meta=np.ndarray>
# Dimensions without coordinates: nbnd
# Data variables:
#     TREFHT     (member, time, lat, lon) float32 3GB dask.array<chunksize=(1, 1248, 96, 144), meta=np.ndarray>
# Attributes: (12/18)
#     Conventions:                          CF-1.0
#     source:                               CAM
#     logname:                              czarakas
#     initial_file:                         /glade/p/cesmdata/cseg/inputdata/ce...
# ...

# %%
ds = coup_ppe.access.load.load_ppe(
    ensemble="pisom",
    varname=["TREFHT", "TS", ""],
    component="atm",
    frequency="month_1",
)

ds
# Out:
# <xarray.Dataset> Size: 7GB
# Dimensions:    (member: 37, time: 1620, lat: 96, lon: 144, nbnd: 2)
# Coordinates:
#   * member     (member) int64 296B 0 1 3 4 5 6 7 8 9 ... 30 31 32 33 34 35 36 37
#   * time       (time) object 13kB 0050-01-16 12:00:00 ... 0184-12-16 12:00:00
#   * lat        (lat) float64 768B -90.0 -88.11 -86.21 ... 86.21 88.11 90.0
#   * lon        (lon) float64 1kB 0.0 2.5 5.0 7.5 ... 350.0 352.5 355.0 357.5
#     time_bnds  (time, nbnd) object 26kB dask.array<chunksize=(1620, 2), meta=np.ndarray>
# Dimensions without coordinates: nbnd
# Data variables:
#     TREFHT     (member, time, lat, lon) float32 3GB dask.array<chunksize=(1, 1248, 96, 144), meta=np.ndarray>
#     TS         (member, time, lat, lon) float32 3GB dask.array<chunksize=(1, 1248, 96, 144), meta=np.ndarray>
# Attributes: (12/18)
#     Conventions:                          CF-1.0
#     source:                               CAM
#     logname:                              czarakas
# ...

# %%
ds
# Out:
# <xarray.Dataset> Size: 7GB
# Dimensions:    (member: 37, time: 1620, lat: 96, lon: 144, nbnd: 2)
# Coordinates:
#   * member     (member) int64 296B 0 1 3 4 5 6 7 8 9 ... 30 31 32 33 34 35 36 37
#   * time       (time) object 13kB 0050-01-16 12:00:00 ... 0184-12-16 12:00:00
#   * lat        (lat) float64 768B -90.0 -88.11 -86.21 ... 86.21 88.11 90.0
#   * lon        (lon) float64 1kB 0.0 2.5 5.0 7.5 ... 350.0 352.5 355.0 357.5
#     time_bnds  (time, nbnd) object 26kB dask.array<chunksize=(1620, 2), meta=np.ndarray>
# Dimensions without coordinates: nbnd
# Data variables:
#     TREFHT     (member, time, lat, lon) float32 3GB dask.array<chunksize=(1, 1248, 96, 144), meta=np.ndarray>
#     TS         (member, time, lat, lon) float32 3GB dask.array<chunksize=(1, 1248, 96, 144), meta=np.ndarray>
# Attributes: (12/18)
#     Conventions:                          CF-1.0
#     source:                               CAM
#     logname:                              czarakas
# ...

# %%
import xarray as xr

# %%
var = "TSA"
comp = "lnd"

case = "f.e21.FHIST_BGC.f19_f19_mg17.historical.coupPPE.000"

indir = "/glade/derecho/scratch/bbuchovecky/archive"
month = xr.open_mfdataset(f"{indir}/{case}/lnd/proc/tseries/month_1/{case}.clm2.h0.{var}.*.nc")
day = xr.open_mfdataset(f"{indir}/{case}/lnd/proc/tseries/day_1/{case}.clm2.h2.{var}.*.nc")

# %%
# month.chunk({"time":60}).TSA
month.TSA
# Out:
# <xarray.DataArray 'TSA' (time: 780, lat: 96, lon: 144)> Size: 43MB
# dask.array<open_dataset-TSA, shape=(780, 96, 144), dtype=float32, chunksize=(1, 96, 144), chunktype=numpy.ndarray>
# Coordinates:
#   * lon      (lon) float32 576B 0.0 2.5 5.0 7.5 10.0 ... 350.0 352.5 355.0 357.5
#   * lat      (lat) float32 384B -90.0 -88.11 -86.21 -84.32 ... 86.21 88.11 90.0
#   * time     (time) object 6kB 1950-02-01 00:00:00 ... 2015-01-01 00:00:00
# Attributes:
#     long_name:     2m air temperature
#     units:         K
#     cell_methods:  time: mean

# %%
day.TSA.isel(time=3).plot()

# %%
import xarray as xr
import matplotlib.pyplot as plt

# %%
d = '/glade/derecho/scratch/bbuchovecky/archive/f.e21.FHIST_BGC.f19_f19_mg17.historical.coupPPE.cplhist/cpl/hist'
hist = [
    f'{d}/f.e21.FHIST_BGC.f19_f19_mg17.historical.coupPPE.cplhist.cpl.ha2x3h.2014-12-01.nc',
    f'{d}/f.e21.FHIST_BGC.f19_f19_mg17.historical.coupPPE.cplhist.cpl.ha2x3h.2014-12-02.nc',
    f'{d}/f.e21.FHIST_BGC.f19_f19_mg17.historical.coupPPE.cplhist.cpl.ha2x1hi.2014-12-01.nc',
    f'{d}/f.e21.FHIST_BGC.f19_f19_mg17.historical.coupPPE.cplhist.cpl.ha2x1hi.2014-12-02.nc',
]

# %%
das = []
for f in hist:
    das.append(xr.open_dataset(f))

# %%
das[2]
# Out:
# <xarray.Dataset> Size: 5MB
# Dimensions:            (time: 24, ntb: 2, a2x1hi_ny: 96, a2x1hi_nx: 144)
# Coordinates:
#   * time               (time) object 192B 2014-12-01 00:30:00 ... 2014-12-01 ...
# Dimensions without coordinates: ntb, a2x1hi_ny, a2x1hi_nx
# Data variables:
#     time_bnds          (time, ntb) object 384B ...
#     a2x1hi_Faxa_swndr  (time, a2x1hi_ny, a2x1hi_nx) float32 1MB ...
#     a2x1hi_Faxa_swvdr  (time, a2x1hi_ny, a2x1hi_nx) float32 1MB ...
#     a2x1hi_Faxa_swndf  (time, a2x1hi_ny, a2x1hi_nx) float32 1MB ...
#     a2x1hi_Faxa_swvdf  (time, a2x1hi_ny, a2x1hi_nx) float32 1MB ...
# Attributes:
#     file_version:   cpl7v10
#     model_doi_url:

# %%
das[0].time
# Out:
# <xarray.DataArray 'time' (time: 8)> Size: 64B
# array([cftime.DatetimeNoLeap(2014, 12, 1, 1, 30, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(2014, 12, 1, 4, 30, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(2014, 12, 1, 7, 30, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(2014, 12, 1, 10, 30, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(2014, 12, 1, 13, 30, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(2014, 12, 1, 16, 30, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(2014, 12, 1, 19, 30, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(2014, 12, 1, 22, 30, 0, 0, has_year_zero=True)],
#       dtype=object)
# Coordinates:
#   * time     (time) object 64B 2014-12-01 01:30:00 ... 2014-12-01 22:30:00
# Attributes:
#     bounds:   time_bnds

# %%
das[1].time
# Out:
# <xarray.DataArray 'time' (time: 8)> Size: 64B
# array([cftime.DatetimeNoLeap(2014, 12, 2, 1, 30, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(2014, 12, 2, 4, 30, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(2014, 12, 2, 7, 30, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(2014, 12, 2, 10, 30, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(2014, 12, 2, 13, 30, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(2014, 12, 2, 16, 30, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(2014, 12, 2, 19, 30, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(2014, 12, 2, 22, 30, 0, 0, has_year_zero=True)],
#       dtype=object)
# Coordinates:
#   * time     (time) object 64B 2014-12-02 01:30:00 ... 2014-12-02 22:30:00
# Attributes:
#     bounds:   time_bnds

# %%
das[0].sel(time='2014-12-01 01:30').a2x3h_Sa_ptem.plot()
